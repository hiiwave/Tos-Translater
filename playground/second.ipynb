# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tos_languagematcher import Matcher
from pathlib import Path

# %%
lang_en_path = Path('data/lang-en')
lang_tw_path = Path('data/lang-tw')
# lang_entw_path = Path('data/lang-en-tw-20180222')
output_path = Path('output/')

# %%
matcher = Matcher(lang_en_path, lang_tw_path)
# Out:
# Matching.. ETC.tsv
# Matching.. INTL.tsv
# Matching.. ITEM.tsv
# Matching.. QUEST.tsv
# Matching.. QUEST_JOBSTEP.tsv
# Matching.. QUEST_LV_0100.tsv
# Matching.. QUEST_LV_0200.tsv
# Matching.. QUEST_LV_0300.tsv
# Matching.. QUEST_LV_0400.tsv
# Matching.. QUEST_UNUSED.tsv
# Matching.. SKILL.tsv
# Matching.. UI.tsv

# %%
matcher.export('en', 'tw', output_path)

# %%
matcher.export()['ITEM.tsv']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-1a664b077577> in <module>()
# ----> 1 matcher.export()['ITEM.tsv']
#
# ~\Documents\01_Personal\tos\Tos-LanguageMatcher\tos_languagematcher\matcher.py in export(self)
#      57             dfm = self.tables[tsv]
#      58             df = pd.merge(df1, dfm, on='korean', how='left')
# ---> 59             df['result'] = np.where(df['name_y'].isna(), df['name'], df['name_y'])
#      60             dfs[tsv] = df
#      61         return dfs
#
# NameError: name 'np' is not defined

# %%
matcher.tables['ITEM.tsv']
# Out:
#                        no_x  \
# 0      ITEM_20150317_000001
# 1      ITEM_20150317_000002
# 2      ITEM_20150317_000003
# 3      ITEM_20150317_000004
# 4      ITEM_20150317_000005
# 5      ITEM_20150317_000006
# 6      ITEM_20150317_000007
# 7      ITEM_20150317_000008
# 8      ITEM_20150317_000009
# 9      ITEM_20150317_000010
# 10     ITEM_20150317_000011
# 11     ITEM_20150317_000012
# 12     ITEM_20150317_000013
# 13     ITEM_20150317_000014
# 14     ITEM_20150317_000015
# 15     ITEM_20150317_000016
# 16     ITEM_20150317_000017
# 17     ITEM_20150317_000018
# 18     ITEM_20150317_000019
# 19     ITEM_20150317_000020
# 20     ITEM_20150317_000021
# 21     ITEM_20150317_000022
# 22     ITEM_20150317_000023
# 23     ITEM_20150317_000024
# 24     ITEM_20150317_000025
# 25     ITEM_20150317_000026
# 26     ITEM_20150317_000027
# 27     ITEM_20150317_000028
# 28     ITEM_20150317_000029
# 29     ITEM_20150317_000030
# ...                     ...
# 17555                   NaN
# 17556                   NaN
# 17557                   NaN
# 17558                   NaN
# 17559                   NaN
# 17560                   NaN
# 17561                   NaN
# 17562                   NaN
# 17563                   NaN
# 17564                   NaN
# 17565                   NaN
# 17566                   NaN
# 17567                   NaN
# 17568                   NaN
# 17569                   NaN
# 17570                   NaN
# 17571                   NaN
# 17572                   NaN
# 17573                   NaN
# 17574                   NaN
# 17575                   NaN
# 17576                   NaN
# 17577                   NaN
# 17578                   NaN
# 17579                   NaN
# 17580                   NaN
# 17581                   NaN
# 17582                   NaN
# 17583                   NaN
# 17584                   NaN
#
#                                                   name_x  \
# 0                                           Empty_helmet
# 1                                        Murmillo Helmet
# 2                                          Empty_armband
# 3                                            Red Armband
# 4                                                Armband
# 5                                        Knotted Armband
# 6                                           Long Armband
# 7                                        Feather Armband
# 8                                       Tasseled Armband
# 9                                           Empty_weapon
# 10                                         Crude Gladius
# 11                              One-handed Sword [Slash]
# 12     A standard weapon for the soldiers from the Ro...
# 13                                               Gladius
# 14     This weapon is an improved version of its mili...
# 15                                          Low Falchion
# 16               This sword is exceptional for slashing.
# 17                                           Low Kaskara
# 18     Due to its ease in manufacturing, this sword i...
# 19                                             Cinquedea
# 20     Recommended for those who desire a heavier and...
# 21                                                 Sabre
# 22     Primary weapon of the cavalry, optimized for s...
# 23                                              Shamshir
# 24     The blade's large crescent edge cuts with imme...
# 25                                              Scimitar
# 26     Its heavy weight is compensated by its very po...
# 27                                                  Kris
# 28     Its twisted edge amplifies the damage it infli...
# 29                                           Snickersnee
# ...                                                  ...
# 17555                                                NaN
# 17556                                                NaN
# 17557                                                NaN
# 17558                                                NaN
# 17559                                                NaN
# 17560                                                NaN
# 17561                                                NaN
# 17562                                                NaN
# 17563                                                NaN
# 17564                                                NaN
# 17565                                                NaN
# 17566                                                NaN
# 17567                                                NaN
# 17568                                                NaN
# 17569                                                NaN
# 17570                                                NaN
# 17571                                                NaN
# 17572                                                NaN
# 17573                                                NaN
# 17574                                                NaN
# 17575                                                NaN
# 17576                                                NaN
# 17577                                                NaN
# 17578                                                NaN
# 17579                                                NaN
# 17580                                                NaN
# 17581                                                NaN
# 17582                                                NaN
# 17583                                                NaN
# 17584                                                NaN
#
#                                                   korean  \
# 0                                              없음_helmet
# 1                                                무르밀로 헬멧
# 2                                             없음_armband
# 3                                                 붉은 암밴드
# 4                                                    암밴드
# 5                                                매듭진 암밴드
# 6                                                  긴 암밴드
# 7                                              깃털 장식 암밴드
# 8                                                술달린 암밴드
# 9                                              없음_weapon
# 10                                             조악한 글라디우스
# 11                                               한손검[베기]
# 12             글라디우스는 왕국 병사의 기본 무장 중 하나로 민간에서도 널리 사용됩니다.
# 13                                                 글라디우스
# 14                           군용에 비해 성능 향상의 여지를 두고 제조됩니다.
# 15                                                 로우 폴쳔
# 16                                     베기 성능이 우수한 검입니다.
# 17                                               로우 카스카라
# 18                    제조가 쉬워서 모험가들이 처음 검을 바꿀 때 많이 선택합니다.
# 19                                                  친퀘데아
# 20                             더 무겁고 더 강한 검을 원한다면 권장합니다.
# 21                                                   사브르
# 22     기병들의 기본 무장이며, 베기에 적합한 구조를 지녔습니다. 검병이 있어 손을 보호하...
# 23                                                   샴시르
# 24                           크게 구부러진 초승달 검날이 베기에 위력적입니다.
# 25                                                   시미터
# 26                       무게는 약간 부담스럽지만, 베기에는 그만큼 위력적입니다.
# 27                                                   크리스
# 28         구불구불한 날이 피해를 크게 입힙니다. 장식과 실용성을 동시에 추구하는 검입니다.
# 29                                                 스니커스니
# ...                                                  ...
# 17555  재료 아이템을 무작위로 1개 획득할 수 있습니다.{nl}사이코키노, 링커, 헌터, ...
# 17556                                        재료 랜덤 상자:4차
# 17557                                    몬스터 카드 행운 상자:2차
# 17558                                            고급스런 상자
# 17559                                          던전 헤택 패키지
# 17560  사용 시 던전 배수 토큰, 인스턴스 던전 소탕권을 얻을 수 있습니다.{nl}마우스 ...
# 17561                                              딸기 사탕
# 17562                                              소다 사탕
# 17563                                              레몬 사탕
# 17564                                             여신의 보주
# 17565                                        대지의 탑 징표 상자
# 17566                    대지의 탑 징표 중 무작위로 1개를 획득할 수 있습니다.
# 17567                                          순백의 신부 부케
# 17568                                          5월의 신부 부케
# 17569  적은 재료로 315제 장비를 제작 가능한 레서피를 선택할 수 있습니다. 마우스 오른...
# 17570                                           팀 창고 확장권
# 17571                                    클래스 코스튬 상자 (7일)
# 17572                             사용시 7일 기간제 코스튬을 획득합니다.
# 17573                                         회색 레서판다 상자
# 17574  마우스 오른쪽 클릭으로 사용가능하며, 사용시 바로 컴패니언으로 등록됩니다. {nl}...
# 17575                                         특별한 변신 스크롤
# 17576                                       변신하는 스크롤입니다.
# 17577  마우스 오른쪽 클릭으로 사용가능하며, 사용시 바로 컴패니언으로 등록됩니다. {nl}...
# 17578                                          산타 코스튬(남)
# 17579                                          산타 코스튬(여)
# 17580  마우스 오른쪽 클릭으로 사용 가능하며, 사용 시 바로 컴패니언으로 등록됩니다. {n...
# 17581  복실복실 황금개 헬멧 코스튬입니다. 우클릭으로 착용하면 외형이 변경됩니다. 염색약의...
# 17582  24K 금괴 멍멍 헬멧 코스튬입니다. 우클릭으로 착용하면 외형이 변경됩니다. 염색약...
# 17583  누구인지 알 수 없지만 길티네 날개를 보았다고 주장하는 자가 만든 날개입니다. 단,...
# 17584  얼음 결정을 본따 만든 날개입니다. 단, 실제 비행은 불가능합니다.{nl} 리사이클...
#
#                        no_y                                             name_y
# 0      ITEM_20150317_000001                                                NaN
# 1      ITEM_20150317_000002                                              角鬥士頭盔
# 2      ITEM_20150317_000003                                          無_armband
# 3      ITEM_20150317_000004                                               赤紅臂環
# 4      ITEM_20150317_000005                                                 臂環
# 5      ITEM_20150317_000006                                               結繩臂環
# 6      ITEM_20150317_000007                                                長臂環
# 7      ITEM_20150317_000008                                               羽毛臂環
# 8      ITEM_20150317_000009                                               流蘇臂環
# 9      ITEM_20150317_000010                                           無_weapon
# 10     ITEM_20150317_000011                                               劣質短劍
# 11     ITEM_20150317_000012                                            單手劍[斬擊]
# 12     ITEM_20150317_000013                          短劍是王國士兵的基本武器之一，在民間也被廣泛使用。
# 13     ITEM_20150317_000014                                                 短劍
# 14     ITEM_20150317_000015                                         性能比軍用劍還要好。
# 15     ITEM_20150317_000016                                              低階偃月刀
# 16     ITEM_20150317_000017                                          斬擊性能優越的劍。
# 17     ITEM_20150317_000018                                            低階卡斯卡拉劍
# 18     ITEM_20150317_000019                               製造容易，冒險家們初次換劍時會經常選擇。
# 19     ITEM_20150317_000020                                                五指劍
# 20     ITEM_20150317_000021                               如果想要更重、更強的劍，建議就是這一把。
# 21     ITEM_20150317_000022                                                 軍刀
# 22     ITEM_20150317_000023                   騎兵們的基本武裝，擁有適合斬擊的構造。有劍柄，也有保護手的效果。
# 23     ITEM_20150317_000024                                                 彎刀
# 24     ITEM_20150317_000025                                很彎曲像新月的劍刃，在斬擊上很有威力。
# 25     ITEM_20150317_000026                                                單刃刀
# 26     ITEM_20150317_000027                              重量有一點重，但是在斬擊上具有相對的威力。
# 27     ITEM_20150317_000028                                                波形刀
# 28     ITEM_20150317_000029                   彎彎曲曲的劍刃可造成嚴重的傷害。是一把同時追求裝飾和實用性的劍。
# 29     ITEM_20150317_000030                                                 刺刀
# ...                     ...                                                ...
# 17555  ITEM_20170522_014923        可以隨機獲得1個材料道具。{nl}裡面裝有念力法師、鎖鏈法師、工兵、獵人相關怪物寶石。
# 17556  ITEM_20170522_014924                                            隨機材料箱IV
# 17557  ITEM_20170522_014927                                          怪物卡片幸運箱II
# 17558  ITEM_20170522_014928                                               高級箱子
# 17559  ITEM_20170522_014929                                             副本回饋禮包
# 17560  ITEM_20170522_014930   點擊滑鼠右鍵時可獲得組合物品。{nl} -即時副本倍數VIP x2{nl} -副本掃盪卷 x2"
# 17561  ITEM_20170522_014935                                              草莓棒棒糖
# 17562  ITEM_20170522_014936                                              蘇打棒棒糖
# 17563  ITEM_20170522_014937                                              檸檬棒棒糖
# 17564  ITEM_20170522_014948                                              女神的寶珠
# 17565  ITEM_20170526_014949                                            大地之塔標誌箱
# 17566  ITEM_20170526_014950  開啟箱子後可以隨機獲得下列目錄中的1項道具。{nl} - 派伊羅艾庫的標誌 1個{nl} -...
# 17567  ITEM_20170619_014974                                             純白新娘捧花
# 17568  ITEM_20170619_014976                                               新娘捧花
# 17569  ITEM_20170717_015025                      可選擇用少量材料製作315級裝備的圖面，點擊滑鼠右鍵使用。
# 17570  ITEM_20170803_015263                                            隊伍倉庫擴張劵
# 17571  ITEM_20170818_015341                                          職業套裝箱(7天)
# 17572  ITEM_20170818_015342                                    使用時可以獲得7天期間制套裝。
# 17573  ITEM_20170915_015372                                               救世熊箱
# 17574  ITEM_20170928_015654  點擊右鍵可以直接使用，點擊之後寵物就會自動登錄。 {nl} 寵物就算沒有騎乘功能玩家也可以騎...
# 17575  ITEM_20170928_015685                                             特別變身卷軸
# 17576  ITEM_20170928_015686                                           用於變身的卷軸。
# 17577  ITEM_20171213_016887  點擊右鍵可以直接使用，點擊之後寵物就會自動登錄。{nl}- 寵物就算沒有騎乘功能玩家也可以騎...
# 17578  ITEM_20171228_017157                                            聖誕套裝(男)
# 17579  ITEM_20171228_017158                                            聖誕套裝(女)
# 17580  ITEM_20171228_017159  點擊右鍵可以直接使用，點擊之後寵物就會自動登錄。{nl}- 寵物就算沒有騎乘功能玩家也可以騎...
# 17581  ITEM_20180205_017207                     黃金財犬玩偶頭套，點擊右鍵使用即可改變外觀，不能使用染色藥。
# 17582  ITEM_20180205_017208                   24K金財犬玩偶頭套，點擊右鍵使用即可改變外觀，不能使用染色藥。
# 17583  ITEM_20180206_017223  雖說不知道是誰，但這是親眼見過吉特涅翅膀的目擊者所製作的翅膀，可是這個翅膀不能飛行。{nl}...
# 17584  ITEM_20180206_017224               仿造冰塊結晶製作的翅膀，但是不能飛行。{nl}可以到回收商店用代幣交換。
#
# [17585 rows x 5 columns]

# %%
matcher.df_ens['ITEM.tsv']
# Out:
#                          no  \
# 0      ITEM_20150317_000001
# 1      ITEM_20150317_000002
# 2      ITEM_20150317_000003
# 3      ITEM_20150317_000004
# 4      ITEM_20150317_000005
# 5      ITEM_20150317_000006
# 6      ITEM_20150317_000007
# 7      ITEM_20150317_000008
# 8      ITEM_20150317_000009
# 9      ITEM_20150317_000010
# 10     ITEM_20150317_000011
# 11     ITEM_20150317_000012
# 12     ITEM_20150317_000013
# 13     ITEM_20150317_000014
# 14     ITEM_20150317_000015
# 15     ITEM_20150317_000016
# 16     ITEM_20150317_000017
# 17     ITEM_20150317_000018
# 18     ITEM_20150317_000019
# 19     ITEM_20150317_000020
# 20     ITEM_20150317_000021
# 21     ITEM_20150317_000022
# 22     ITEM_20150317_000023
# 23     ITEM_20150317_000024
# 24     ITEM_20150317_000025
# 25     ITEM_20150317_000026
# 26     ITEM_20150317_000027
# 27     ITEM_20150317_000028
# 28     ITEM_20150317_000029
# 29     ITEM_20150317_000030
# ...                     ...
# 17520  ITEM_20180208_017521
# 17521  ITEM_20180208_017522
# 17522  ITEM_20180208_017523
# 17523  ITEM_20180208_017524
# 17524  ITEM_20180208_017525
# 17525  ITEM_20180208_017526
# 17526  ITEM_20180208_017527
# 17527  ITEM_20180208_017528
# 17528  ITEM_20180208_017529
# 17529  ITEM_20180208_017530
# 17530  ITEM_20180208_017531
# 17531  ITEM_20180208_017532
# 17532  ITEM_20180208_017533
# 17533  ITEM_20180208_017534
# 17534  ITEM_20180208_017535
# 17535  ITEM_20180208_017536
# 17536  ITEM_20180208_017537
# 17537  ITEM_20180208_017538
# 17538  ITEM_20180208_017539
# 17539  ITEM_20180208_017540
# 17540  ITEM_20180208_017541
# 17541  ITEM_20180208_017542
# 17542  ITEM_20180208_017543
# 17543  ITEM_20180208_017544
# 17544  ITEM_20180208_017545
# 17545  ITEM_20180208_017546
# 17546  ITEM_20180208_017547
# 17547  ITEM_20180208_017548
# 17548  ITEM_20180228_017549
# 17549  ITEM_20180228_017550
#
#                                                     name  \
# 0                                           Empty_helmet
# 1                                        Murmillo Helmet
# 2                                          Empty_armband
# 3                                            Red Armband
# 4                                                Armband
# 5                                        Knotted Armband
# 6                                           Long Armband
# 7                                        Feather Armband
# 8                                       Tasseled Armband
# 9                                           Empty_weapon
# 10                                         Crude Gladius
# 11                              One-handed Sword [Slash]
# 12     A standard weapon for the soldiers from the Ro...
# 13                                               Gladius
# 14     This weapon is an improved version of its mili...
# 15                                          Low Falchion
# 16               This sword is exceptional for slashing.
# 17                                           Low Kaskara
# 18     Due to its ease in manufacturing, this sword i...
# 19                                             Cinquedea
# 20     Recommended for those who desire a heavier and...
# 21                                                 Sabre
# 22     Primary weapon of the cavalry, optimized for s...
# 23                                              Shamshir
# 24     The blade's large crescent edge cuts with imme...
# 25                                              Scimitar
# 26     Its heavy weight is compensated by its very po...
# 27                                                  Kris
# 28     Its twisted edge amplifies the damage it infli...
# 29                                           Snickersnee
# ...                                                  ...
# 17520                         Baby Pig Companion Voucher
# 17521  A Companion Voucher obtained as an Adventure J...
# 17522                        Armadillo Companion Voucher
# 17523  A Companion Voucher obtained as an Adventure J...
# 17524                                             Amulet
# 17525  A relic containing the spirits of the Nak Muay...
# 17526                                 Red Meduja Essence
# 17527  Essence obtained from a Red Meduja. It can be ...
# 17528                                  Bright Ellom Bell
# 17529  Bright Ellom bells are a special kind of Ellom...
# 17530                                    Spirit Medicine
# 17531                                    House Sculpture
# 17532  A little house sculpted by Tesla. It was made ...
# 17533                                          Dandelion
# 17534  A dandelion flower grown at the Inner Enceinte...
# 17535                                    Dandelion Spore
# 17536                    Quest Item. Right-click to use.
# 17537  Spores from an Inner Enceinte District dandelion.
# 17538  A box discovered around a tomb. It feels like ...
# 17539  A letter discovered inside the box. Someone wr...
# 17540                                         Stonecrops
# 17541  Stonecrops from Akmens Ridge. They symbolize a...
# 17542                                            Statice
# 17543  Statice from Cranto Coast. They represent eter...
# 17544                                 Strawberry Cupcake
# 17545  A small treat made to soothe a spirit with a s...
# 17546                                         Iona's Box
# 17547     A gift from Iona to appease a departed spirit.
# 17548                                                NaN
# 17549                                                NaN
#
#                                                   korean
# 0                                              없음_helmet
# 1                                                무르밀로 헬멧
# 2                                             없음_armband
# 3                                                 붉은 암밴드
# 4                                                    암밴드
# 5                                                매듭진 암밴드
# 6                                                  긴 암밴드
# 7                                              깃털 장식 암밴드
# 8                                                술달린 암밴드
# 9                                              없음_weapon
# 10                                             조악한 글라디우스
# 11                                               한손검[베기]
# 12             글라디우스는 왕국 병사의 기본 무장 중 하나로 민간에서도 널리 사용됩니다.
# 13                                                 글라디우스
# 14                           군용에 비해 성능 향상의 여지를 두고 제조됩니다.
# 15                                                 로우 폴쳔
# 16                                     베기 성능이 우수한 검입니다.
# 17                                               로우 카스카라
# 18                    제조가 쉬워서 모험가들이 처음 검을 바꿀 때 많이 선택합니다.
# 19                                                  친퀘데아
# 20                             더 무겁고 더 강한 검을 원한다면 권장합니다.
# 21                                                   사브르
# 22     기병들의 기본 무장이며, 베기에 적합한 구조를 지녔습니다. 검병이 있어 손을 보호하...
# 23                                                   샴시르
# 24                           크게 구부러진 초승달 검날이 베기에 위력적입니다.
# 25                                                   시미터
# 26                       무게는 약간 부담스럽지만, 베기에는 그만큼 위력적입니다.
# 27                                                   크리스
# 28         구불구불한 날이 피해를 크게 입힙니다. 장식과 실용성을 동시에 추구하는 검입니다.
# 29                                                 스니커스니
# ...                                                  ...
# 17520                                      아기돼지 컴패니언 교환권
# 17521  모험일지 보상으로 얻은 아기돼지 컴패니언 교환권, 바이보라 날개에게서 교환권 20개...
# 17522                                     아르마딜로 컴패니언 교환권
# 17523  모험일지 보상으로 얻은 아르마딜로 컴패니언 교환권, 바이보라 날개에게서 교환권 20...
# 17524                                                호신부
# 17525  낙무아이 마스터의 스승 영혼이 깃든 물품. 사용 시 스승 영혼이 낙무아이 마스터와의...
# 17526                                         붉은 미듀쟈의 정수
# 17527  영혼과 접촉한 경험이 있는 붉은 미듀쟈의 정수. 이것을 활용하면 영혼이 물건에 접촉...
# 17528                                         영롱한 엘룸의 방울
# 17529  영롱한 엘룸의 방울은 영혼의 힘에 의해 변형 된 겁니다. 이 방울은 병들어 죽은 영...
# 17530                                아파하는 영혼을 치유하기 위한 약.
# 17531                                              집 조각상
# 17532         조각가 테슬라가 조각한 집. 집에 가지 못한 영혼을 위로하기 위해 조각했다.
# 17533                                               좀민들레
# 17534  내성곽지구에서 자라는 민들레. 석화저주로 인해 생물이 잘 자라지 못한 환경임에도 자...
# 17535                                            좀민들레 홀씨
# 17536                        퀘스트 아이템, 마우스 오른쪽 버튼 클릭으로 사용
# 17537                              내성곽지구에서 자라는 좀민들레의 홀씨.
# 17538                   묘지에서 발견한 상자. 뭔가가 잔뜩 들어있는 듯 묵직하다.
# 17539         상자에서 나온 편지지. 편지에는 누군가를 향한 애정이 담긴 내용이 적혀있다.
# 17540                                                기린초
# 17541      아크멘스 능선에서 자란 기린초. 기린초의 꽃말은 소녀의 사랑을 의미한다고 합니다.
# 17542                                               스타티스
# 17543      크란토 연안에서 자란 스타티스. 스타티스의 꽃말은 영원한 사랑을 의미한다고 한다.
# 17544                                              딸기 과자
# 17545                              영혼을 위로하기 위해 만든 딸기 과자.
# 17546                                          이오나가 준 상자
# 17547                             영혼을 위로하기 위해 이오나가 만든 상자
# 17548  스태미나를 30 회복 시켜줍니다.{nl}사용가능 목록{nl} - 벨하이더 {nl} ...
# 17549  펭귄의 건강을 책임지는 먹이입니다. 펭귄의 HP를 모두 회복하고 스태미나가 +15 ...
#
# [17550 rows x 3 columns]
